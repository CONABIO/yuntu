# %%
from yuntu import Audio

# %%
audio = Audio("https://www2.cs.uic.edu/~i101/SoundFiles/taunt.wav")
# Out:
# https://www2.cs.uic.edu/~i101/SoundFiles/taunt.wav: 90KB [00:00, 229.70KB/s]

# %%
channel1 = audio.get_channel(0)

# %%
channel1.listen()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
channel1.features.db_spectrogram().plot()

# %%
channel1.plot()

# %%
channel1
