# %%
import sys
sys.path.insert(0, '../')

# %% [markdown]
# # Audio

# %%
from yuntu.core.audio.audio import Audio

# %%
SAMPLE_PATH = '/Users/erobredo/Downloads/11k16bitpcm.wav'
audio = Audio(SAMPLE_PATH)

# %%
spec = audio.features.db_spectrogram()

# %%
cut_no_pad = spec.cut(min_freq=3000, max_freq=10000, start_time=10, end_time=16)
cut_pad = spec.cut(
    min_freq=3000,
    max_freq=10000,
    start_time=10,
    end_time=16,
    pad=True,
    pad_mode='constant',
    constant_values=spec.min())

# %%
cut_pad.plot()
